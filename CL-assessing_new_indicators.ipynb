# %% [markdown]
# # Statistics new Dataset
# Una volta prodotto il nuovo dataset controlliamo distribuziooni e statistiche delle nuove variabili

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("dataset/CL_Raw-dataset.csv", sep="\t", index_col=0, decimal=",")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5575 entries, 0 to 5574
# Data columns (total 21 columns):
# CustomerID      5575 non-null object
# I               5575 non-null int64
# Iu              5575 non-null int64
# Imax            5575 non-null int64
# E               5575 non-null float64
# PIL             5575 non-null float64
# Mb              5575 non-null float64
# MbPIL           5575 non-null float64
# Mt              5575 non-null float64
# TsM             5575 non-null float64
# TsW             5575 non-null float64
# Ts              5575 non-null float64
# NbxM            5575 non-null float64
# NbxW            5575 non-null float64
# MeanD           5575 non-null float64
# MaxD            5575 non-null float64
# MinD            5575 non-null float64
# Etrim           5575 non-null float64
# Emonth          5575 non-null float64
# Eday_of_week    5575 non-null float64
# Ehour           5575 non-null float64
# dtypes: float64(17), int64(3), object(1)
# ...

# %% [markdown]
# df.describe()

# %% [markdown]
# ## Statistics

# %% [markdown]
# ### I

# %%
df['I'].plot.kde(bw_method=7)

# %% [markdown]
# ## Iu

# %%
df['Iu'].plot.kde(bw_method=3.5)

# %% [markdown]
# ## Imax
#
# I è il numero di elementi acquistati ossia la somma delle quantità

# %%
df['Imax'].plot.kde(bw_method=3)

# %% [markdown]
# ## E
# I è il numero di elementi acquistati ossia la somma delle quantità

# %%
df['E'].plot.kde()

# %%
df["E"].plot.box()

# %% [markdown]
# ## Pil
#
# Da inserire grafico che mostra il pil ossia la nazione

# %%
df_pil = pd.read_csv("dataset/Country_PIL.csv", sep=";", decimal=",",index_col=0)
dict_pil={}
for index, row in df_pil.iterrows():
    dict_pil[row["PIL"]]=row["Country"]

# %%
temp_pil=df.copy()
temp_pil["Coutry"]="N"
for index, row in temp_pil.iterrows():
    temp_pil.loc[index]=dict_pil[row["PIL"]]

# %%
temp_pil.groupby("Coutry")["CustomerID"].count().plot.bar()

# %% [markdown]
# ## Mb

# %%
df["Mb"].plot.kde(bw_method=3)

# %% [markdown]
# ## Mb/PIL

# %%
df["MbPIL"].plot.kde(bw_method=3)

# %% [markdown]
# ## Mt

# %%
df["Mt"].plot.kde(bw_method=4)

# %% [markdown]
# ## TsM

# %%
df["Mt"].plot.kde(bw_method=4)

# %% [markdown]
# ## TsW

# %%
df["Mt"].plot.kde(bw_method=4)

# %% [markdown]
# ## Ts

# %%
df["Ts"].plot.kde(bw_method=3)

# %% [markdown]
# ## NbxM

# %%
df["NbxM"].plot.kde(bw_method=3)

# %% [markdown]
# ## NbxW

# %%
df["NbxW"].plot.kde(bw_method=3)

# %% [markdown]
# ## Mean day

# %%
df["MeanD"].plot.kde(bw_method=3)

# %% [markdown]
# ## Min
# Essendo tutti i valori = 0 non è possibile la rappresentazione

# %% [markdown]
# ## MaxD

# %%
df["MaxD"].plot.kde(bw_method=3)

# %% [markdown]
# ## entropy date trimestri

# %%
df["Etrim"].plot.kde()

# %% [markdown]
# ## entropy date month

# %%
df["Emonth"].plot.kde()

# %% [markdown]
# ## entropy date week

# %%
df["Eday_of_week"].plot.kde()

# %% [markdown]
# ## Outliers

# %%
df.boxplot(column=['MaxD'])
df[df["MaxD"]> 230]
# Out:
#      CustomerID     I   Iu  Imax         E    PIL          Mb       MbPIL  \
# 20      17924.0  1160   26   120  4.607264  2.567  423.214286  164.867271
# 30      12838.0   359  115    12  6.806296  2.567  341.565000  133.059992
# 31      13255.0   177   13    72  3.700440  2.567  199.755000   77.816517
# 36      15983.0   892   82    48  6.202706  2.567  368.755000  143.652123
# 43      17181.0   241   23   144  4.523562  2.567  119.960000   46.731593
# ...         ...   ...  ...   ...       ...    ...         ...         ...
# 2439    13736.0   497  166    12  7.311696  2.567  365.950000  142.559408
# 2485    14851.0   325   28    30  4.807355  2.567  255.675000   99.600701
# 2591    14023.0   345   30    36  4.889680  2.567  292.035000  113.765095
# 2625    13525.0   394    5   160  2.251629  2.567  314.390000  122.473705
# 2772    16933.0   285   42    36  5.379753  2.567  279.140000  108.741722
#
#               Mt         TsM  ...       Ts      NbxM      NbxW       MeanD  \
# ...

# %%
df.boxplot(column=['I'])
df[df["I"] > 50000]
# Out:
#      CustomerID       I    Iu  Imax          E    PIL           Mb  \
# 15      17511.0   63149   452   600   8.429370  2.567  2856.657419
# 35      13694.0   62328   364  1600   8.301292  2.567  1271.106000
# 65      14911.0   77125  1743   640  10.176595  0.229   665.029590
# 216     14156.0   57100   713  1440   9.138729  0.229  2111.774630
# 399     17450.0   69051   123  1944   6.470956  2.567  4217.056222
# 456     18102.0   64124   150  1008   6.733942  2.567  4327.621667
# 757     14298.0   58343   884   900   9.546671  2.567  1171.075000
# 936     14646.0  196556   699  2400   8.948579  0.875  3871.916944
# 1053    12415.0   77032   441  1152   8.596237  1.271  6512.930526
#
#             MbPIL          Mt           TsM  ...         Ts       NbxM  \
# 15    1112.838886   93.315469   6812.029231  ...   88556.38   2.384615
# 35     495.171796  113.491607   4888.869231  ...   63555.30   3.846154
# 65    2904.059344   23.733669   9975.443846  ...  129680.77  15.000000
# ...

# %%
df.boxplot(column=['Iu'])
df[df["Iu"]>750]
# Out:
#      CustomerID      I    Iu  Imax          E    PIL           Mb  \
# 46      12748.0  24079  1755   576  10.348166  2.567   150.352108
# 65      14911.0  77125  1743   640  10.176595  0.229   665.029590
# 71      17841.0  22891  1319   288   9.572718  2.567   325.834032
# 93      14606.0   6159   810    96   9.212985  2.567   132.688989
# 757     14298.0  58343   884   900   9.546671  2.567  1171.075000
# 4234    14096.0  16336  1118   108   9.710527  2.567  3132.848824
#
#             MbPIL         Mt          TsM  ...         Ts       NbxM  \
# 46      58.571137   6.757398  2359.371538  ...   30671.83  15.692308
# 65    2904.059344  23.733669  9975.443846  ...  129680.77  15.000000
# 71     126.931840   5.229539  3107.955385  ...   40403.42   9.538462
# 93      51.690296   4.463084   908.409231  ...   11809.32   6.846154
# 757    456.203740  31.476665  3963.638462  ...   51527.30   3.384615
# 4234  1220.431953  10.453078  4096.802308  ...   53258.43   1.307692
#
# ...

# %%
df.boxplot(column=['E'])
df[df["E"]>10]
# Out:
#    CustomerID      I    Iu  Imax          E    PIL          Mb        MbPIL  \
# 46    12748.0  24079  1755   576  10.348166  2.567  150.352108    58.571137
# 65    14911.0  77125  1743   640  10.176595  0.229  665.029590  2904.059344
#
#            Mt          TsM  ...         Ts       NbxM      NbxW     MeanD  \
# 46   6.757398  2359.371538  ...   30671.83  15.692308  3.849057  1.470588
# 65  23.733669  9975.443846  ...  129680.77  15.000000  3.679245  1.512821
#
#     MaxD  MinD     Etrim    Emonth  Eday_of_week     Ehour
# 46  30.0   0.0  1.993581  2.829463      2.481182  2.939470
# 65  17.0   0.0  2.056074  3.342288      2.517958  3.189957
#
# [2 rows x 21 columns]

# %%
df.boxplot(column="Etrim")
df[df["Etrim"]> 1.5]
# Out:
#      CustomerID     I   Iu  Imax         E    PIL          Mb       MbPIL  \
# 1       13047.0  1386  105    32  6.503112  2.567  356.232222  138.773752
# 2       12583.0  4992  113   360  6.504979  2.752  442.969333  160.962694
# 5       15291.0  2102   61   144  5.737287  2.567  330.235714  128.646558
# 6       14688.0  3580  147   120  6.809252  2.567  265.100952  103.272673
# 7       17809.0  2017   46   144  5.440224  2.567  445.492500  173.545968
# ...         ...   ...  ...   ...       ...    ...         ...         ...
# 3617    15329.0   482   49    25  5.563178  2.567  341.066667  132.865862
# 3652    15253.0   866   52    48  5.690185  2.567  183.640000   71.538761
# 3659    12697.0   503   36    72  5.142664  0.534  252.530000  472.902622
# 3661    12615.0  1365   81    96  6.232275  2.752  523.297500  190.151708
# 3702    13461.0  1170   14   100  3.736007  2.567  481.666667  187.637969
#
#              Mt         TsM  ...       Ts      NbxM      NbxW      MeanD  \
# ...

# %%
df.boxplot(column="Ts")
df[df["Ts"]>50000]
# Out:
#      CustomerID       I    Iu  Imax          E    PIL           Mb  \
# 8       15311.0   37932   567   288   8.656355  2.567   666.581222
# 12      16029.0   32203    41  2400   4.929618  2.567   969.897500
# 15      17511.0   63149   452   600   8.429370  2.567  2856.657419
# 35      13694.0   62328   364  1600   8.301292  2.567  1271.106000
# 65      14911.0   77125  1743   640  10.176595  0.229   665.029590
# 162     15061.0   28782    70   500   5.513475  2.567  1133.165417
# 216     14156.0   57100   713  1440   9.138729  0.229  2111.774630
# 227     17949.0   28148    27  1992   4.261198  2.567  1351.273500
# 242     15769.0   27660    18  1200   3.857473  2.567  2072.948800
# 255     13089.0   31005   636   288   8.772797  2.567   617.209362
# 399     17450.0   69051   123  1944   6.470956  2.567  4217.056222
# 456     18102.0   64124   150  1008   6.733942  2.567  4327.621667
# 757     14298.0   58343   884   900   9.546671  2.567  1171.075000
# ...

# %%
df.boxplot(column="Imax")
df[df["Mb"]>3500]
# Out:
#      CustomerID       I   Iu  Imax         E    PIL            Mb  \
# 235        336N     863   75   108  6.228819  2.567   4946.420000
# 394      79978N     926  325    29  8.344296  2.567   3547.770000
# 399     17450.0   69051  123  1944  6.470956  2.567   4217.056222
# 445      55064N     928   72   104  6.169925  2.567   5363.170000
# 456     18102.0   64124  150  1008  6.733942  2.567   4327.621667
# 659      43644N    1047   73   115  6.189825  2.567   6207.480000
# 672     12753.0   11381  132   192  6.875455  5.928   3554.565000
# 770      88877N    1511   75   213  6.228819  2.567   7439.290000
# 936     14646.0  196556  699  2400  8.948579  0.875   3871.916944
# 988      43584N    1671   84   215  6.349649  2.567  11870.010000
# 1053    12415.0   77032  441  1152  8.596237  1.271   6512.930526
# 1161    15749.0   10314    5  3114  2.251629  2.567  12425.450000
# 1336    14088.0   12593  378   100  8.424730  2.567   3878.114615
# ...

# %%
df.boxplot(column="PIL")
df[df["PIL"]>4.5]
# Out:
#      CustomerID      I   Iu  Imax         E     PIL        Mb       MbPIL  \
# 316     12763.0    316   16    60  3.947703   5.928   247.040   41.673414
# 560     12755.0   1491    4  1488  2.000000   5.928  1905.975  321.520749
# 672     12753.0  11381  132   192  6.875455   5.928  3554.565  599.622976
# 1615    12754.0   6481   49   576  5.532835   5.928  1003.580  169.294872
# 2860    12733.0    137   22    36  4.459432  15.265   383.950   25.152309
# 3155    12770.0    743   12    96  3.584963   5.928  1351.450  227.977395
# 3636    12798.0   5256    6  2040  2.405639   5.928  2325.680  392.321188
# 4384    12756.0    144    4    72  2.000000   5.928   112.080   18.906883
# 4943    12646.0    897   43    72  5.402964  15.265   673.485   44.119555
# 4990    12812.0    164   15    24  3.906891   5.928   229.640   38.738192
#
#               Mt          TsM  ...        Ts      NbxM      NbxW       MeanD  \
# ...

# %% [markdown]
# ## Correlation

# %%
import seaborn as sns
df.corr()
fig, ax = plt.subplots(figsize=(15,10))         # Sample figsize in inches
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True, linewidths=1.5, ax= ax)
heatmap.set_title('HeatMap correlazione nuovi indicatori', fontdict={'fontsize':12}, pad=10)
# Out:
# Text(0.5, 1, 'HeatMap correlazione nuovi indicatori')

# %% [markdown]
# Le colonne da eliminare perchè dipendenti dal tempo sono:
# * I
# * Iu
# * Ts

# %%
del df['I']
del df['Iu']
del df['Ts']

# %%
df.corr()
fig, ax = plt.subplots(figsize=(15,10))         # Sample figsize in inches
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True, linewidths=1.5, ax= ax)
heatmap.set_title('HeatMap correlazione nuovi indicatori', fontdict={'fontsize':12}, pad=10)
# Out:
# Text(0.5, 1, 'HeatMap correlazione nuovi indicatori')

# %% [markdown]
# Le colonne da eliminare per l'alta correlazione sono:
#
# * TsM o TsW
# * NbxM o NbxW
# * MaxD, MinD
# * Etrim o Emonth o Eday_of_week o Ehour(lasciarne 1)

# %%
import seaborn as sns
del df['MbPIL']
del df['TsM']
del df['NbxM']
del df['MaxD']
del df['MinD']
del df['Emonth']
del df['Etrim']
del df['Ehour']
df.corr()
fig, ax = plt.subplots(figsize=(15,10))         # Sample figsize in inches
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True, linewidths=1.5, ax= ax)
heatmap.set_title('HeatMap correlazione nuovi indicatori', fontdict={'fontsize':12}, pad=10)
# Out:
# Text(0.5, 1, 'HeatMap correlazione nuovi indicatori')
